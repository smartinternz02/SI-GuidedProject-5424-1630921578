# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.kdeplot(iris.loc[(iris['species']=='setosa'),'sepal_length'],color='b',label='setosa')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.kdeplot(iris.loc[(iris['species']=='setosa'),'sepal_length'],color='b',label='setosa')
sns.kdeplot(iris.loc[(iris['species']=='versicolor'),'sepal_length'],color='r',label='version')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.relplot(data=iris,x="sepal_length",y="sepal_width")

# %%
sns.relplot(data=iris,x="petal_length",y="petal_width")

# %%
sns.kdeplot(iris.loc[(iris['species']=='setosa'),'sepal_length'],color='b',label='setosa')
sns.kdeplot(iris.loc[(iris['species']=='versicolor'),'sepal_length'],color='r',label='version')
sns.kdeplot(iris.loc[(iris['species']=='virginica'),'sepal_length'],color='g',label='virgin')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.boxplot(x='sepal_length',y='sepal_width',data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris=np.random.randn(1000)
plt.hist(iris)
# Out:
# (array([ 11.,  52., 104., 219., 268., 199., 107.,  32.,   7.,   1.]),
#  array([-2.97508679, -2.31212171, -1.64915662, -0.98619154, -0.32322645,
#          0.33973863,  1.00270372,  1.6656688 ,  2.32863389,  2.99159897,
#          3.65456406]),
#  <BarContainer object of 10 artists>)

# %%
labels='car','scooty','truck','bus'
sizes=[225,130,245,210]
colors=['r','b','g','c']
explode=(0.1,0,0,0)
plt.pie(sizes,explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow=True)
plt.axis('equal')
plt.show()

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=iris,height=5)

# %%
iris_feat = iris.iloc[:,:-1]
iris_species = iris.iloc[:,-1]

# %%
colors = {'setosa':'r', 'virginica':'g', 'versicolor':'b'}

# create a figure and axis
fig, ax = plt.subplots()
# plot each data-point
for i in range(len(iris_feat['sepal_length'])):
    ax.scatter(iris_feat['sepal_length'][i], iris_feat['sepal_width'][i],color=colors[iris_species[i]])
# set a title and labels
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
ax.set_title('Iris Dataset')
ax.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
